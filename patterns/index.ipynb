# %% [markdown]
# 1. Dynamic Programming
#
# Key insights to recognize a DP problem
#
# 1️⃣ Optimal Substructure → "The solution to a larger problem depends on solutions to its subproblems."
#
#     Example: "Find the shortest path," "Maximize profit," "Minimize cost."
#
# 2️⃣ Overlapping Subproblems → "Same smaller problems are solved multiple times."
#
#     Example: Fibonacci sequence, Knapsack problem.
#
# 3️⃣ Decision Making at Each Step → "Choose between multiple options and optimize the result."
#
#     Example: "Pick or skip an item," "Cut or not cut a rod," "Merge or not merge intervals."
#
# 4️⃣ Counting Ways / Number of Ways → "Find all possible ways to reach a target."
#
#     Example: "How many ways to make change for X?"
#
# 5️⃣ "Min/Max/Longest/Shortest" in the problem statement → Suggests DP for optimization.
#
#     Example: "Find the longest increasing subsequence," "Find the minimum cost path."
#
# 6️⃣ Constraints Suggest Feasibility of DP → If constraints are small (~10⁴ or less), DP is often a viable approach.
#
#     Example: 1D DP O(N), 2D DP O(N²), Bitmask DP O(2^N * N).
#
# 7️⃣ Subsequences / Partitions / Intervals → Often solved with DP.
#
#     Example: "Find the longest palindromic subsequence," "Partition the array into k groups."
#
# 8️⃣ Grid-Based Problems → Usually solved with 2D DP.
#
#     Example: "Find the number of ways to reach the bottom-right of a grid."
#
# 9️⃣ String Transformations → Edit distance, Longest Common Subsequence (LCS), etc.
#
# 🔟 Recursive Brute Force Works But is Slow → If recursion causes TLE, memoization or bottom-up DP can optimize it.

# %% [markdown]
# 2. Graphs
#
# Hints to determine if a problem can be solved using a graph
#
# 1️⃣ Is the problem about "nodes" and "edges"?
#
#     If yes, it’s likely a graph problem.
#
# 2️⃣ Are there relationships between elements (dependencies, paths, connections)?
#
#     If yes, it suggests graph traversal (BFS/DFS).
#
# 3️⃣ Does the problem involve finding the "shortest" or "cheapest" path?
#
#     If yes, it suggests Dijkstra/BFS/Bellman-Ford.
#
# 4️⃣ Does the problem involve dependencies or ordering?
#
#     If yes, it suggests Topological Sorting (DAGs).
#
# 5️⃣ Does the problem involve a cycle or checking for a cyclic dependency?
#
#     If yes, use DFS or Union-Find.
#
# 6️⃣ Are you given a grid where you can move in multiple directions?
#
#     Convert it into a graph problem (treat each cell as a node).
#
# **BFS in a graph**
#
# Where can be used:
#
# ✅ Find the shortest path in an unweighted graph
#
#     BFS explores level-by-level, ensuring the first time it reaches a node is via the shortest path.
#     Example: Shortest path in a maze, shortest transformation sequence in a word ladder.
#
# ✅ Searching for the closest target (first occurrence of something)
#
#     If the problem requires finding the nearest X, BFS guarantees the first match is the closest.
#     Example: Nearest exit in a grid, shortest distance to a water source.
#
# ✅ Multi-source shortest paths (spreading problems)
#
#     When there are multiple starting points (like rot spreading or fire spreading).
#     Example: "Rotting Oranges" (Leetcode 994), "Knight's Minimum Moves."
#
# ✅ When memory is not a major concern
#
#     BFS can use more memory (stores all nodes at a level), so avoid it for deep trees or large graphs.
#
# 🚀 BFS Clues in Problem Statement
#
#     “Find the shortest path in an unweighted graph”
#     “Find the minimum number of moves”
#     “Find the nearest X”
#     “Level-by-level traversal required”
